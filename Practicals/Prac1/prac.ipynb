# %% [markdown]
# PRACTICAL 1

# %%
import pandas as pd
import seaborn as sb

# %%
data = pd.read_csv('mystery.csv', header=None)

# %%
grid = sb.PairGrid(data)
grid.map(sb.regplot)

# %%
corr = data.corr()
sb.set_style("white")
sb.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
